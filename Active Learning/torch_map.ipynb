# %%
import torch
import os

def load_txt_as_ground_truth(txt_path):
    boxes = []
    labels = []

    if os.path.exists(txt_path):
        with open(txt_path, 'r') as f:
            for line in f:
                parts = line.strip().split()
                if len(parts) != 5:
                    continue
                cls, x1, y1, x2, y2 = map(float, parts)
                labels.append(int(cls))
                boxes.append([x1, y1, x2, y2])

    if boxes:
        return {
            "boxes": torch.tensor(boxes, dtype=torch.float32),
            "labels": torch.tensor(labels, dtype=torch.int64)
        }
    else:
        # Return empty tensors if no annotations or file doesn't exist
        return {
            "boxes": torch.zeros((0, 4), dtype=torch.float32),
            "labels": torch.zeros((0,), dtype=torch.int64)
        }

# Example: load GTs for a list of images
img_dir = "/home/umang.shikarvar/CycleGAN/lucknow_airshed/test/images"
label_dir = "/home/umang.shikarvar/CycleGAN/lucknow_airshed/test/labels"  # .txt files with same name as image but .txt extension

image_filenames = sorted([
    f for f in os.listdir(img_dir)
    if f.lower().endswith('.tif')
])

gt_targets = []

for img_file in image_filenames:
    base_name = os.path.splitext(img_file)[0]
    txt_file = os.path.join(label_dir, base_name + ".txt")
    gt = load_txt_as_ground_truth(txt_file)
    gt_targets.append(gt)

# %%
print(gt_targets)
# Out:
# [{'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([[430., 224., 459., 250.]]), 'labels': tensor([1])}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([[298., 555., 325., 578.]]), 'labels': tensor([1])}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([[280., 259., 307., 293.]]), 'labels': tensor([1])}, {'boxes': tensor([[228.,  73., 252.,  92.]]), 'labels': tensor([2])}, {'boxes': tensor([[358., 564., 378., 591.],
#         [473., 551., 498., 587.],
#         [376., 521., 396., 551.]]), 'labels': tensor([2, 1, 2])}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([[ 52., 216.,  81., 238.]]), 'labels': tensor([1])}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([[221., 435., 242., 457.],
#         [260., 330., 295., 356.],
#         [270., 121., 299., 158.]]), 'labels': tensor([2, 1, 1])}, {'boxes': tensor([[606., 494., 631., 520.],
#         [559., 460., 583., 487.],
#         [479., 397., 503., 428.],
#         [319., 385., 337., 414.],
#         [527., 304., 552., 324.],
#         [446., 259., 470., 283.]]), 'labels': tensor([2, 2, 2, 1, 2, 1])}, {'boxes': tensor([[442., 462., 474., 489.],
#         [514., 411., 540., 436.]]), 'labels': tensor([1, 1])}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([[586.,  95., 618., 124.],
#         [414.,  28., 444.,  57.]]), 'labels': tensor([2, 2])}, {'boxes': tensor([[414., 604., 444., 633.],
#         [413., 536., 442., 564.],
#         [248., 489., 280., 515.],
#         [443., 475., 478., 512.],
#         [426., 394., 454., 425.],
#         [435., 355., 461., 384.],
#         [276., 309., 288., 337.],
#         [449., 294., 475., 318.],
#         [138., 261., 169., 302.],
#         [320., 246., 349., 270.],
#         [467., 161., 496., 191.],
#         [131.,  29., 158.,  55.]]), 'labels': tensor([2, 2, 1, 1, 2, 1, 1, 1, 2, 2, 1, 1])}, {'boxes': tensor([[131., 605., 158., 631.],
#         [ 91., 563., 120., 591.],
#         [330., 515., 361., 540.],
#         [118., 505., 143., 533.],
#         [ 94., 500., 125., 530.],
#         [ 30., 494.,  55., 520.],
#         [384., 473., 417., 503.],
#         [ 81., 270., 114., 295.],
#         [115., 244., 142., 268.],
#         [545., 147., 573., 176.]]), 'labels': tensor([1, 2, 2, 2, 1, 2, 1, 1, 1, 2])}, {'boxes': tensor([[41.,  4., 71., 34.]]), 'labels': tensor([1])}, {'boxes': tensor([[ 41., 580.,  71., 610.]]), 'labels': tensor([1])}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([[534., 250., 559., 274.]]), 'labels': tensor([1])}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([[ 10.,  95.,  42., 124.]]), 'labels': tensor([2])}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([[609., 243., 637., 271.]]), 'labels': tensor([0])}, {'boxes': tensor([[561., 570., 583., 593.],
#         [482., 422., 508., 432.],
#         [306., 383., 330., 404.],
#         [ 77., 224., 100., 244.],
#         [517., 192., 542., 215.],
#         [106.,  34., 133.,  54.]]), 'labels': tensor([2, 1, 2, 2, 2, 1])}, {'boxes': tensor([[106., 610., 133., 630.],
#         [232., 541., 261., 572.],
#         [116., 518., 147., 544.]]), 'labels': tensor([1, 2, 1])}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([[120., 282., 141., 309.]]), 'labels': tensor([1])}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([[ 33., 243.,  61., 271.],
#         [491.,  66., 517.,  93.]]), 'labels': tensor([0, 0])}, {'boxes': tensor([[481., 407., 511., 437.],
#         [531., 388., 563., 420.],
#         [527., 231., 556., 259.],
#         [215., 218., 242., 242.],
#         [610., 144., 635., 172.]]), 'labels': tensor([0, 1, 0, 1, 1])}, {'boxes': tensor([[176., 533., 202., 558.]]), 'labels': tensor([2])}, {'boxes': tensor([[119., 575., 144., 594.]]), 'labels': tensor([2])}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([[499., 307., 521., 335.]]), 'labels': tensor([1])}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([[437., 479., 458., 498.],
#         [527.,   6., 551.,  23.]]), 'labels': tensor([2, 2])}, {'boxes': tensor([[527., 582., 551., 599.]]), 'labels': tensor([2])}, {'boxes': tensor([[ 72., 445., 100., 472.],
#         [304., 247., 327., 270.],
#         [ 78., 242., 105., 268.],
#         [112., 212., 136., 236.],
#         [ 34., 144.,  59., 172.],
#         [282.,  84., 310., 113.],
#         [197.,  82., 230., 114.],
#         [512.,  83., 534., 107.],
#         [409.,  63., 433.,  76.]]), 'labels': tensor([1, 2, 0, 0, 1, 1, 0, 2, 2])}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([[593., 105., 626., 133.],
#         [579.,  49., 608.,  73.]]), 'labels': tensor([1, 1])}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([[579., 533., 607., 562.],
#         [328., 378., 355., 406.],
#         [280., 118., 314., 143.]]), 'labels': tensor([1, 0, 1])}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([[123.,  67., 154.,  98.]]), 'labels': tensor([2])}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([[ 81., 419., 102., 445.]]), 'labels': tensor([2])}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([[ 17., 105.,  50., 133.],
#         [  3.,  49.,  32.,  73.]]), 'labels': tensor([1, 1])}, {'boxes': tensor([[227., 143., 247., 173.],
#         [276.,  57., 299.,  73.]]), 'labels': tensor([1, 1])}, {'boxes': tensor([[360., 544., 378., 573.],
#         [321., 387., 348., 420.]]), 'labels': tensor([2, 1])}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([[534.,  90., 563., 115.]]), 'labels': tensor([2])}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([[  3., 533.,  31., 562.]]), 'labels': tensor([1])}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([[523., 454., 547., 477.]]), 'labels': tensor([2])}, {'boxes': tensor([[389., 270., 416., 292.],
#         [314.,  50., 344.,  78.]]), 'labels': tensor([1, 1])}, {'boxes': tensor([[480., 316., 511., 341.]]), 'labels': tensor([1])}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([[406., 505., 433., 531.],
#         [ 57., 447.,  87., 474.],
#         [455., 554., 486., 584.],
#         [518., 387., 546., 411.],
#         [479., 360., 506., 391.],
#         [518., 342., 546., 367.],
#         [132., 279., 159., 299.],
#         [173., 262., 187., 288.],
#         [ 47., 223.,  78., 250.],
#         [385., 196., 419., 224.],
#         [400., 106., 425., 127.]]), 'labels': tensor([1, 1, 2, 2, 1, 1, 2, 2, 2, 1, 2])}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([[516., 461., 549., 502.],
#         [607., 342., 634., 376.],
#         [446., 513., 472., 543.]]), 'labels': tensor([1, 1, 1])}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([[207.,  16., 233.,  34.]]), 'labels': tensor([2])}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([[563.,  46., 587.,  67.]]), 'labels': tensor([2])}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([[245., 462., 274., 491.],
#         [162., 366., 187., 396.],
#         [109., 308., 137., 335.],
#         [ 72., 250., 104., 276.],
#         [236., 198., 269., 229.]]), 'labels': tensor([2, 2, 0, 1, 1])}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([[526., 512., 558., 541.]]), 'labels': tensor([0])}, {'boxes': tensor([[ 52., 429.,  88., 457.],
#         [402., 377., 440., 408.],
#         [ 31., 342.,  58., 376.],
#         [394., 338., 425., 375.],
#         [587., 140., 619., 167.]]), 'labels': tensor([1, 1, 1, 1, 1])}, {'boxes': tensor([[159., 552., 185., 579.]]), 'labels': tensor([0])}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([[ 24., 429.,  51., 451.]]), 'labels': tensor([2])}, {'boxes': tensor([[ 89., 159., 121., 192.]]), 'labels': tensor([1])}, {'boxes': tensor([[ 98., 497., 127., 525.]]), 'labels': tensor([1])}, {'boxes': tensor([[ 79., 401., 109., 436.],
#         [535.,  26., 559.,  60.]]), 'labels': tensor([2, 1])}, {'boxes': tensor([[535., 602., 559., 636.]]), 'labels': tensor([1])}, {'boxes': tensor([[155., 542., 185., 563.]]), 'labels': tensor([1])}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([[400., 314., 425., 342.],
#         [487., 190., 510., 206.],
#         [430.,  20., 456.,  45.]]), 'labels': tensor([1, 2, 0])}, {'boxes': tensor([[430., 596., 456., 621.],
#         [249., 332., 266., 357.],
#         [237., 180., 270., 205.]]), 'labels': tensor([0, 2, 1])}, {'boxes': tensor([[496., 337., 516., 361.],
#         [477., 178., 503., 202.],
#         [559., 151., 577., 169.]]), 'labels': tensor([2, 2, 0])}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([[381., 185., 408., 219.],
#         [ 11., 140.,  43., 167.],
#         [209., 133., 235., 159.]]), 'labels': tensor([1, 1, 0])}, {'boxes': tensor([[488., 298., 523., 328.]]), 'labels': tensor([1])}, {'boxes': tensor([[474., 501., 506., 528.]]), 'labels': tensor([1])}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([[403., 305., 433., 328.],
#         [405., 286., 436., 312.]]), 'labels': tensor([2, 1])}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([[ 58., 452.,  78., 476.],
#         [200., 389., 227., 411.],
#         [ 71., 344.,  93., 370.]]), 'labels': tensor([2, 2, 2])}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([[290.,  17., 312.,  39.]]), 'labels': tensor([2])}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([[ 63., 535.,  92., 545.],
#         [280., 329., 312., 367.]]), 'labels': tensor([1, 1])}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([[142., 484., 167., 506.]]), 'labels': tensor([1])}, {'boxes': tensor([[405., 451., 422., 480.]]), 'labels': tensor([1])}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([[526., 187., 550., 217.]]), 'labels': tensor([1])}, {'boxes': tensor([[174., 521., 202., 552.],
#         [205., 522., 239., 546.],
#         [ 86., 373., 117., 395.],
#         [117., 304., 146., 327.],
#         [236., 236., 253., 261.]]), 'labels': tensor([2, 2, 1, 2, 1])}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([[526., 595., 552., 623.],
#         [549., 449., 572., 473.]]), 'labels': tensor([2, 2])}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([[589., 519., 622., 537.],
#         [254., 327., 281., 357.]]), 'labels': tensor([1, 1])}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([[577., 544., 604., 565.],
#         [223., 130., 245., 161.]]), 'labels': tensor([1, 1])}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([[105.,  60., 136.,  85.]]), 'labels': tensor([1])}, {'boxes': tensor([[399., 365., 423., 384.],
#         [132., 271., 156., 288.]]), 'labels': tensor([1, 2])}, {'boxes': tensor([[503., 222., 523., 251.]]), 'labels': tensor([1])}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([[335., 251., 364., 268.]]), 'labels': tensor([1])}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([[605., 187., 632., 210.],
#         [475.,  89., 504., 121.],
#         [608.,  34., 631.,  54.]]), 'labels': tensor([2, 1, 2])}, {'boxes': tensor([[608., 610., 631., 630.],
#         [577., 571., 600., 601.]]), 'labels': tensor([2, 1])}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([[241., 290., 266., 315.],
#         [ 98., 253., 123., 272.],
#         [ 72., 133.,  95., 154.]]), 'labels': tensor([2, 2, 2])}, {'boxes': tensor([[327., 398., 349., 424.],
#         [ 95., 386., 118., 404.],
#         [ 40., 371.,  64., 395.],
#         [194., 300., 220., 326.],
#         [526., 185., 552., 219.],
#         [448., 151., 467., 175.],
#         [285., 117., 310., 143.],
#         [456.,  77., 474.,  96.],
#         [589.,  22., 612.,  43.]]), 'labels': tensor([2, 2, 2, 2, 1, 2, 1, 2, 2])}, {'boxes': tensor([[589., 598., 612., 619.],
#         [412., 500., 435., 526.],
#         [556., 494., 574., 516.],
#         [116., 421., 140., 447.],
#         [312., 366., 337., 384.],
#         [470., 329., 494., 357.],
#         [ 78., 320., 102., 341.],
#         [509., 209., 531., 236.],
#         [415., 171., 446., 199.],
#         [216., 137., 242., 162.],
#         [140.,  38., 161.,  63.],
#         [ 34.,  18.,  67.,  45.]]), 'labels': tensor([2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 1])}, {'boxes': tensor([[140., 614., 161., 639.],
#         [ 34., 594.,  67., 621.],
#         [348., 551., 372., 572.],
#         [310., 480., 337., 502.],
#         [118., 437., 146., 466.],
#         [462., 238., 486., 265.],
#         [237., 102., 261., 129.],
#         [329.,  71., 354.,  94.]]), 'labels': tensor([2, 1, 2, 2, 2, 2, 2, 2])}, {'boxes': tensor([[437., 490., 457., 514.],
#         [394., 400., 417., 427.]]), 'labels': tensor([2, 2])}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([[ 13., 519.,  46., 537.],
#         [296., 365., 315., 392.]]), 'labels': tensor([1, 1])}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([[  1., 544.,  28., 565.]]), 'labels': tensor([1])}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([[474.,  36., 491.,  65.]]), 'labels': tensor([1])}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([[220., 533., 238., 560.],
#         [273., 518., 292., 549.],
#         [140., 521., 161., 541.],
#         [505., 514., 530., 532.],
#         [ 52., 466.,  78., 492.],
#         [325., 393., 359., 414.],
#         [102., 350., 128., 373.],
#         [379., 295., 404., 322.],
#         [386., 159., 404., 184.],
#         [402.,  49., 427.,  64.]]), 'labels': tensor([1, 1, 1, 2, 2, 1, 1, 2, 2, 1])}, {'boxes': tensor([[402., 625., 427., 640.],
#         [263., 516., 291., 543.],
#         [ 61., 486.,  80., 510.],
#         [322., 245., 350., 270.]]), 'labels': tensor([1, 1, 2, 2])}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([[ 51., 509.,  76., 536.],
#         [163., 467., 180., 487.],
#         [ 32., 610.,  55., 630.],
#         [  1., 571.,  24., 601.]]), 'labels': tensor([2, 1, 2, 1])}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([[13., 22., 36., 43.]]), 'labels': tensor([2])}, {'boxes': tensor([[ 13., 598.,  36., 619.],
#         [233., 544., 258., 574.],
#         [184., 478., 210., 505.],
#         [113., 473., 137., 492.],
#         [236., 249., 268., 285.],
#         [ 60., 145.,  86., 175.],
#         [ 93.,  68., 124.,  96.]]), 'labels': tensor([2, 1, 2, 2, 1, 2, 2])}, {'boxes': tensor([[ 34., 573.,  66., 598.],
#         [ 74., 372., 103., 395.],
#         [119., 253., 138., 271.]]), 'labels': tensor([1, 2, 2])}, {'boxes': tensor([[138.,  21., 164.,  49.]]), 'labels': tensor([2])}, {'boxes': tensor([[138., 597., 164., 625.],
#         [373., 546., 390., 572.]]), 'labels': tensor([2, 2])}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([[254., 446., 281., 477.]]), 'labels': tensor([2])}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([[144., 574., 168., 601.]]), 'labels': tensor([1])}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([[561., 515., 579., 535.],
#         [463., 449., 496., 469.]]), 'labels': tensor([1, 1])}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([[160., 171., 188., 197.]]), 'labels': tensor([1])}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([[563., 324., 579., 349.],
#         [501.,  85., 531., 112.]]), 'labels': tensor([2, 2])}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([[261., 427., 294., 447.],
#         [290., 335., 313., 347.]]), 'labels': tensor([1, 2])}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([[236., 561., 258., 587.]]), 'labels': tensor([2])}, {'boxes': tensor([[467., 220., 498., 245.]]), 'labels': tensor([1])}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([[160., 153., 176., 186.]]), 'labels': tensor([1])}, {'boxes': tensor([[ 77., 514., 103., 544.]]), 'labels': tensor([2])}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([[551., 376., 575., 406.],
#         [151., 541., 174., 573.],
#         [175., 423., 208., 456.],
#         [335., 421., 358., 448.],
#         [169., 375., 199., 403.],
#         [143., 272., 167., 301.]]), 'labels': tensor([2, 1, 0, 2, 2, 1])}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([[247., 513., 270., 538.],
#         [334., 459., 355., 483.],
#         [360., 301., 380., 325.],
#         [423., 297., 442., 318.],
#         [314., 158., 338., 177.],
#         [ 81.,  81., 106., 101.],
#         [141.,  47., 165.,  77.],
#         [550., 431., 574., 449.],
#         [583., 161., 609., 187.]]), 'labels': tensor([1, 1, 2, 2, 2, 1, 1, 2, 2])}, {'boxes': tensor([[133., 476., 153., 499.],
#         [ 25., 472.,  51., 493.],
#         [131., 464., 157., 487.],
#         [426., 222., 450., 251.]]), 'labels': tensor([2, 2, 1, 2])}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([[501.,  53., 531.,  78.],
#         [383., 351., 405., 377.],
#         [200., 143., 223., 168.],
#         [280., 133., 309., 157.]]), 'labels': tensor([2, 2, 1, 1])}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([[343., 101., 378., 138.]]), 'labels': tensor([2])}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([[ 51., 103.,  68., 130.]]), 'labels': tensor([2])}, {'boxes': tensor([[603., 490., 622., 519.],
#         [463., 190., 485., 217.]]), 'labels': tensor([1, 1])}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([[293., 289., 320., 310.],
#         [521., 141., 540., 169.],
#         [245., 140., 269., 158.],
#         [577., 420., 605., 450.]]), 'labels': tensor([2, 2, 2, 1])}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([[319., 329., 339., 355.],
#         [286., 531., 314., 556.],
#         [236., 520., 266., 547.],
#         [282., 391., 309., 419.]]), 'labels': tensor([1, 2, 2, 2])}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([[434., 571., 461., 600.],
#         [362., 541., 383., 564.],
#         [ 92., 110., 120., 137.]]), 'labels': tensor([2, 2, 2])}, {'boxes': tensor([[423., 557., 445., 588.],
#         [ 44., 524.,  69., 544.],
#         [225., 426., 248., 454.],
#         [334., 380., 356., 407.],
#         [403., 382., 430., 404.],
#         [432., 369., 444., 395.],
#         [ 64., 368.,  91., 391.],
#         [325., 357., 351., 371.],
#         [486., 191., 508., 218.],
#         [  7., 161.,  33., 187.],
#         [243., 107., 260., 131.]]), 'labels': tensor([1, 2, 1, 1, 1, 1, 2, 2, 1, 2, 2])}, {'boxes': tensor([[390., 548., 420., 578.]]), 'labels': tensor([0])}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([[ 77., 288., 101., 312.],
#         [406.,  45., 432.,  65.]]), 'labels': tensor([1, 1])}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([[ 27., 490.,  46., 519.],
#         [ 62., 217.,  89., 232.]]), 'labels': tensor([1, 1])}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([[338., 613., 366., 637.],
#         [451., 526., 476., 549.],
#         [474., 521., 498., 543.],
#         [330., 494., 360., 517.],
#         [173., 274., 197., 301.],
#         [183., 252., 206., 279.],
#         [221., 215., 249., 240.],
#         [355.,  18., 377.,  33.],
#         [121., 556., 150., 575.],
#         [  1., 420.,  29., 450.]]), 'labels': tensor([1, 2, 1, 1, 1, 2, 2, 2, 2, 1])}, {'boxes': tensor([[222., 570., 252., 595.],
#         [203., 522., 234., 551.],
#         [315., 502., 347., 535.],
#         [355., 594., 377., 609.],
#         [572., 441., 588., 470.],
#         [539., 432., 559., 458.],
#         [562., 361., 581., 382.],
#         [416., 282., 441., 307.],
#         [179., 468., 207., 493.],
#         [145., 348., 169., 373.],
#         [ 99., 303., 125., 336.]]), 'labels': tensor([2, 2, 1, 2, 1, 1, 2, 0, 2, 2, 2])}, {'boxes': tensor([[411., 593., 441., 613.],
#         [571., 570., 594., 588.]]), 'labels': tensor([1, 2])}, {'boxes': tensor([[598., 440., 622., 468.],
#         [547., 261., 568., 282.]]), 'labels': tensor([1, 2])}, {'boxes': tensor([[379., 444., 405., 468.],
#         [417., 338., 444., 362.],
#         [154.,  82., 183., 112.]]), 'labels': tensor([2, 2, 2])}, {'boxes': tensor([[ 53., 186.,  74., 213.],
#         [128.,  90., 150., 114.],
#         [397., 533., 417., 561.],
#         [431., 427., 455., 450.]]), 'labels': tensor([2, 2, 2, 2])}, {'boxes': tensor([[214., 495., 243., 526.],
#         [580., 573., 609., 603.],
#         [334., 426., 365., 451.],
#         [490., 421., 521., 445.],
#         [227., 352., 258., 383.]]), 'labels': tensor([2, 1, 2, 1, 0])}, {'boxes': tensor([[281., 293., 307., 321.],
#         [537., 551., 562., 570.],
#         [335., 521., 364., 542.],
#         [430., 425., 465., 459.]]), 'labels': tensor([2, 2, 1, 2])}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([[229., 353., 260., 380.],
#         [253., 282., 275., 309.],
#         [302., 213., 333., 238.]]), 'labels': tensor([1, 1, 1])}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([[212., 173., 243., 203.],
#         [ 20.,  98.,  45., 122.],
#         [ 79.,  65., 105.,  89.]]), 'labels': tensor([2, 2, 2])}, {'boxes': tensor([[259., 530., 283., 559.],
#         [ 63., 508.,  91., 541.],
#         [487., 484., 522., 510.],
#         [233., 455., 259., 479.],
#         [366., 449., 393., 472.],
#         [266., 418., 293., 444.],
#         [475., 364., 497., 390.],
#         [367., 354., 390., 384.],
#         [436., 314., 457., 342.],
#         [255., 229., 289., 260.]]), 'labels': tensor([2, 1, 1, 2, 2, 2, 2, 1, 2, 1])}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([[ 22., 440.,  46., 468.],
#         [126., 342., 149., 366.],
#         [ 98., 283., 122., 308.]]), 'labels': tensor([1, 1, 0])}, {'boxes': tensor([[ 51., 553.,  73., 572.],
#         [578., 430., 605., 458.],
#         [479., 335., 507., 366.]]), 'labels': tensor([1, 2, 1])}, {'boxes': tensor([[240.,  88., 259., 118.]]), 'labels': tensor([1])}, {'boxes': tensor([[233., 578., 252., 595.]]), 'labels': tensor([2])}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([[275., 400., 304., 424.]]), 'labels': tensor([1])}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([[ 47., 206.,  72., 230.],
#         [368.,  72., 397.,  97.]]), 'labels': tensor([2, 1])}, {'boxes': tensor([[ 53., 249.,  74., 276.],
#         [457., 136., 486., 160.]]), 'labels': tensor([2, 2])}, {'boxes': tensor([[404., 237., 426., 262.]]), 'labels': tensor([2])}, {'boxes': tensor([[512., 505., 544., 533.]]), 'labels': tensor([1])}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([[ 38., 105.,  64., 119.],
#         [486.,   6., 507.,  33.]]), 'labels': tensor([2, 2])}, {'boxes': tensor([[486., 582., 507., 609.],
#         [ 66., 576.,  93., 593.],
#         [276., 517., 300., 544.],
#         [569., 500., 598., 526.],
#         [121., 489., 153., 516.],
#         [384., 406., 414., 430.],
#         [456., 397., 478., 422.],
#         [382., 339., 407., 373.],
#         [275., 322., 297., 350.],
#         [532., 314., 559., 341.],
#         [552., 268., 580., 294.],
#         [546.,  65., 581.,  95.]]), 'labels': tensor([2, 1, 1, 1, 1, 1, 2, 1, 1, 2, 1, 1])}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([[568., 507., 589., 532.],
#         [417., 231., 444., 259.]]), 'labels': tensor([2, 1])}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([[  2., 430.,  29., 458.]]), 'labels': tensor([2])}, {'boxes': tensor([[295.,  82., 319., 108.]]), 'labels': tensor([1])}, {'boxes': tensor([[235., 570., 260., 594.],
#         [495., 487., 522., 514.],
#         [572., 438., 603., 467.],
#         [ 80.,  87., 105., 115.]]), 'labels': tensor([2, 2, 1, 2])}, {'boxes': tensor([[516., 388., 538., 411.]]), 'labels': tensor([2])}, {'boxes': tensor([[494., 600., 517., 628.],
#         [577., 173., 604., 204.],
#         [329., 133., 356., 157.]]), 'labels': tensor([1, 1, 1])}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([[ 87., 436., 110., 461.]]), 'labels': tensor([1])}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([[540.,  25., 575.,  57.]]), 'labels': tensor([1])}, {'boxes': tensor([[540., 601., 575., 633.]]), 'labels': tensor([1])}, {'boxes': tensor([[276., 525., 297., 556.],
#         [609., 411., 639., 442.]]), 'labels': tensor([1, 1])}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}, {'boxes': tensor([], size=(0, 4)), 'labels': tensor([], dtype=torch.int64)}]

# %%
def load_txt_as_prediction(txt_path):
    boxes = []
    labels = []
    scores = []

    if os.path.exists(txt_path):
        with open(txt_path, 'r') as f:
            for line in f:
                parts = line.strip().split()
                if len(parts) != 6:
                    continue
                cls, conf, x1, y1, x2, y2 = map(float, parts)
                labels.append(int(cls))
                scores.append(conf)
                boxes.append([x1, y1, x2, y2])

    if boxes:
        return {
            "boxes": torch.tensor(boxes, dtype=torch.float32),
            "labels": torch.tensor(labels, dtype=torch.int64),
            "scores": torch.tensor(scores, dtype=torch.float32)
        }
    else:
        # Return empty prediction if no data
        return {
            "boxes": torch.zeros((0, 4), dtype=torch.float32),
            "labels": torch.zeros((0,), dtype=torch.int64),
            "scores": torch.zeros((0,), dtype=torch.float32)
        }

# %%
prediction_dir = "/home/umang.shikarvar/CycleGAN/lucknow_predictions"

predictions = []

for img_file in image_filenames:
    base_name = os.path.splitext(img_file)[0]
    pred_file = os.path.join(prediction_dir, base_name + ".txt")
    pred = load_txt_as_prediction(pred_file)
    predictions.append(pred)

# %%
def make_class_agnostic(detection_list):
    """
    Sets all labels in each detection dict to class 0
    """
    for d in detection_list:
        d["labels"] = torch.zeros_like(d["labels"])
    return detection_list

# %%
from torchmetrics.detection.mean_ap import MeanAveragePrecision

# Class-agnostic conversion
gt_targets_ca = make_class_agnostic(gt_targets)
predictions_ca = make_class_agnostic(predictions)

# Compute mAP
metric = MeanAveragePrecision()
metric.update(predictions_ca, gt_targets_ca)
results = metric.compute()

print("Class-Agnostic mAP@0.50:", results["map_50"].item())
# Out:
# Class-Agnostic mAP@0.50: 0.7663448452949524
